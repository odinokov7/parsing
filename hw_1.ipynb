# %%
import requests
import json

# %%
url = 'https://api.github.com'
user = 'odinokov7'

# %%
r = requests.get(f'{url}/users/{user}/repos')

# %%
with open('data.json', 'w') as f:
    json.dump(r.json(), f)

# %%
for i in r.json():
    print(i['name'])
# Out:
# 2hw
# 3hw
# 5_hw
# 6_hw
# 7_hw
# first_homework
# numpy-pandas
# parsing
# repo
# repo-github
